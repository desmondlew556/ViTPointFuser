# %%
from packaging import version

import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
import tensorboard as tb

# %% [markdown]
# # Visualize attention maps

# %% [markdown]
# Model configurations:
# 128 hidden size, 2 attention heads, 2 hidden layers, 6 point scale

# %%
import numpy as np
with open("data/attention_probs_for_one_sample","rb") as f:
    data = np.load(f) 
    data = data['attention_score']
heatmap = plt.imshow( data ,  )
plt.colorbar(heatmap)
plt.title( "ViTPointFuser attention score" )
plt.xlabel( "input patch" )
plt.ylabel( "input patch" )
plt.show()

# %% [markdown]
# Model configurations:
# 128 hidden size, 2 attention heads, 2 hidden layers, 6 point scale, MLP head with 512 hidden units, input features include label, confidence score, and x,y coordinates

# %%
import numpy as np
with open("data/attention_probs_for_one_sample_mlp","rb") as f:
    data = np.load(f) 
    data = data['attention_score']
import matplotlib.pyplot as plt
heatmap = plt.imshow( data ,  )
plt.colorbar(heatmap)
plt.title( "ViTPointFuser attention score" )
plt.xlabel( "input patch" )
plt.ylabel( "input patch" )
plt.show()
